# %% [markdown]
# ## Lesson matplotlib Exercises

# %%
import matplotlib.pyplot as plt
print(plt)
# Out:
# <module 'matplotlib.pyplot' from '/Users/luke/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %%
import math
print(math)
# Out:
# <module 'math' from '/Users/luke/opt/anaconda3/lib/python3.7/lib-dynload/math.cpython-37m-darwin.so'>

# %%
import random
print(random)
# Out:
# <module 'random' from '/Users/luke/opt/anaconda3/lib/python3.7/random.py'>

# %%
# Use matplotlib to plot the following equation:
# y = (x ** 2) - x + 2

x = list(range(-20, 20))
y = [i ** 2 - i + 2 for i in x]


plt.plot(x, y)
plt.annotate('Origin', xy=(0,0), xytext = (0, 100),
            arrowprops=dict(facecolor = 'darkorange'))
plt.show()

# %% [markdown]
# ### Exercise 2
# #### Create and label 4 separate charts for the following equations (choose a range for x that makes sense):
#
# - $y = sqrt(x)$
#
# - $y = x^3$
#
# - $y = 2^x$

# %% [markdown]
# #### Equation 1
# - $y = sqrt(x)$

# %%
max_limit = 50

def x_pos_list(x):
    x_num = list(range(x, (x + max_limit)))
    return x_num

values_list = x_pos_list(2)

x2 = list(range(2, 20))
y2 = [math.sqrt(i) for i in x2]

plt.plot(y2)
plt.ylabel('$\sqrt{x}$')
plt.xlabel('$x$')
plt.title("$y = sqrt(x)$")
plt.show()

# %% [markdown]
# #### Equation 2
# - $y = x^3$

# %%
x3 = list(range(-20, 24))
y3 = [y ** 3 for y in x_crange]

plt.plot(x3, y3)
plt.savefig('cubed_figure.pdf')
plt.ylabel('$x^3$')
plt.xlabel('$x$')
plt.title("$y = x^3$")
plt.show()

# %% [markdown]
# #### Equation 3
# - $y = 2^x$

# %%
x4 = list(range(-7, 8))
y4 = [2 ** x for x in x_nth_power]

plt.plot(y_nth_power, c='firebrick')
plt.ylabel("$2^x$", c="rebeccapurple")
plt.xlabel("$x$", c="sienna")
plt.show()

# %% [markdown]
# ### Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
# Configuring plot size
plt.figure(figsize=(16, 9))

# subplots data - except for the first subplot, I am referring to the variables created earlier in the notebook

plt.subplot(2,2,1)
x1 = list(range(-22, 24))
y1 = [i ** 2 - i + 2 for i in x]
plt.plot(x, y)
plt.annotate('Origin', xy=(0,0), xytext = (0, 100),
            arrowprops=dict(facecolor = 'darkorange'))


plt.subplot(2,2,2)
x2p = list(range(2, 24))
y2p = [math.sqrt(i) for i in x2p]
plt.plot(y2p)


plt.subplot(2,2,3)
x3p = list(range(-20, 24))
y3p = [i ** 3 for i in x3p]
plt.plot(x3p, y3p)


plt.subplot(2,2,4)
x4p = list(range(-3, 5))
y4p = [2 ** i for i in x4p]
plt.plot(y4p)


plt.tight_layout(pad = 3.0)
plt.show()

# %%
# Configuring plot size
plt.figure(figsize=(16, 9))

# subplots data - except for the first subplot, I am referring to the variables created earlier in the notebook

plt.subplot(2,2,1)
x1 = list(range(-22, 24))
y1 = [i ** 2 - i + 2 for i in x]
plt.plot(x, y, c = 'darkblue', label = "$y = x^2 - x + 2$")
plt.ylabel('$x^2 - x + 2$')
plt.xlabel('$x$')
plt.annotate('Origin', xy=(0,0), xytext = (0, 100),
            arrowprops=dict(facecolor = 'darkorange'))
plt.legend(loc = 3)
plt.title('Equation 1')

plt.subplot(2,2,2)
x2p = list(range(2, 24))
y2p = [math.sqrt(i) for i in x2p]
plt.plot(y2p, c = 'firebrick', label = "$y = sqrt(x)$")
plt.ylabel('$\sqrt{x}$')
plt.xlabel('$x$')
plt.legend(loc = 2)
plt.title('Equation 2')

plt.subplot(2,2,3)
x3p = list(range(-20, 24))
y3p = [i ** 3 for i in x3p]
plt.plot(x3p, y3p, c = 'forestgreen', label = "$y = x^3$")
plt.ylabel('$x^3$')
plt.xlabel('$x$')
plt.legend(loc = 2)
plt.title('Equation 3')

plt.subplot(2,2,4)
x4p = list(range(-3, 5,))
y4p = [2 ** i for i in x4p]
plt.plot(y4p, c = 'slategray', label = "$y = 2^x")
plt.ylabel("$2^x$")
plt.xlabel("$x$")
plt.legend(loc = 2)
plt.title('Equation 4')

plt.tight_layout(pad = 3.0)
plt.show()
